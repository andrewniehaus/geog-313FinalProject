# %%
### Visualizations sandbox ###

# %%
# # # # Silhouette Plot
# # Description:
# # A silhouette plot shows a bar for each data point, with the length of the bar representing how well the point fits within its assigned cluster.
# # Points with a high silhouette value (close to 1) are well-clustered, while negative values suggest points that might belong to a different cluster.
# # What You See:
# # Bars grouped by cluster, sorted by silhouette value within each cluster.
# # A dashed red line indicating the average silhouette score across all clusters.
# # Interpretation:
# # Ideally, most bars are tall and positive, and the clusters are of roughly equal width (indicating balanced cluster sizes).

# import matplotlib.pyplot as plt
# from sklearn.metrics import silhouette_samples, silhouette_score
# import numpy as np

# # Reshape the valid_data array for silhouette calculation
# valid_data_reshaped = valid_data.reshape(-1, 1)

# # Predict cluster labels for valid data
# cluster_labels = kmeans.predict(valid_data_reshaped)

# # Calculate silhouette scores
# silhouette_vals = silhouette_samples(valid_data_reshaped, cluster_labels)

# # Compute the average silhouette score
# silhouette_avg = silhouette_score(valid_data_reshaped, cluster_labels)
# print(f"Average Silhouette Score: {silhouette_avg:.3f}")

# # Plot silhouette scores
# plt.figure(figsize=(10, 7))
# y_lower = 10  # Initial y-axis position

# for i in range(n_clusters):
#     # Get silhouette scores for cluster i
#     ith_cluster_silhouette_vals = silhouette_vals[cluster_labels == i]
#     ith_cluster_silhouette_vals.sort()
#     size_cluster_i = ith_cluster_silhouette_vals.shape[0]
#     y_upper = y_lower + size_cluster_i

#     # Fill the silhouette scores for each cluster
#     plt.fill_betweenx(
#         np.arange(y_lower, y_upper),
#         0,
#         ith_cluster_silhouette_vals,
#         alpha=0.7,
#         label=f'Cluster {i}'
#     )

#     y_lower = y_upper + 10  # Add spacing between clusters

# # Plot the average silhouette score
# plt.axvline(x=silhouette_avg, color='red', linestyle='--', label='Average Silhouette Score')
# plt.title("Silhouette Plot for KMeans Clustering", fontsize=14)
# plt.xlabel("Silhouette Coefficient Values", fontsize=12)
# plt.ylabel("Cluster Labels", fontsize=12)
# plt.legend(loc='upper right')
# plt.tight_layout()
# plt.show()

# %%
# # # # Elbow Method Plot
# # Description:
# # This plot shows the sum of squared distances (inertia) between points and their cluster centers for different numbers of clusters (k). The goal is to identify the "elbow" point where the reduction in inertia begins to level off.
# # What You See:
# # A line plot with k (number of clusters) on the x-axis and inertia on the y-axis.
# # A sharp downward curve that flattens as k increases.
# # Interpretation:
# # The "elbow" (where the plot bends significantly) suggests the optimal number of clusters. Beyond this point, additional clusters do not significantly improve the clustering.

# import matplotlib.pyplot as plt
# from sklearn.cluster import MiniBatchKMeans

# # Reshape valid_data for clustering (ensure the number of features matches the dataset)
# valid_data_reshaped = valid_data.reshape(-1, 3)  # Assuming 3 features per pixel

# # Define the range of cluster numbers to test
# cluster_range = range(1, 15)
# inertia_values = []

# # Perform KMeans for each number of clusters and store the inertia
# for n_clusters in cluster_range:
#     kmeans = MiniBatchKMeans(n_clusters=n_clusters, random_state=42, batch_size=1024)
#     kmeans.fit(valid_data_reshaped)
#     inertia_values.append(kmeans.inertia_)

# # Plot the elbow curve
# plt.figure(figsize=(10, 6))
# plt.plot(cluster_range, inertia_values, marker='o', linestyle='--', color='b')
# plt.title("Elbow Method for Optimal Clusters", fontsize=14)
# plt.xlabel("Number of Clusters (k)", fontsize=12)
# plt.ylabel("Inertia (Within-Cluster Sum of Squares)", fontsize=12)
# plt.xticks(cluster_range)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.show()

# %%
# # # # 2D Scatter Plot of Clusters
# # Description:
# # A scatter plot where each point represents a data sample, plotted using two features (e.g., two spectral bands or two principal components). Points are colored by their assigned cluster labels.
# # What You See:
# # Colored clusters of points, ideally forming distinct groups.
# # Cluster centroids (if plotted) appear as marked points (e.g., red "x"s) within each cluster.
# # Interpretation:
# # Clear separation between clusters suggests effective clustering. Overlapping points or clusters may indicate poor separation.

# import matplotlib.pyplot as plt

# # Specify the band names for Red and NIR
# red_band = 'red_band_name'  # Replace with the actual name of the red band
# nir_band = 'nir_band_name'  # Replace with the actual name of the NIR band

# # Extract values for the Red and NIR bands
# red_values = final_mosaic[red_band].values.flatten()
# nir_values = final_mosaic[nir_band].values.flatten()

# # Filter out invalid values (e.g., NaN or zero values)
# valid_mask = (~np.isnan(red_values)) & (~np.isnan(nir_values)) & (red_values > 0) & (nir_values > 0)
# red_values = red_values[valid_mask]
# nir_values = nir_values[valid_mask]

# # Create the scatter plot
# plt.figure(figsize=(10, 8))
# plt.scatter(red_values, nir_values, s=1, c='blue', alpha=0.5)

# # Add labels and title
# plt.title("2D Scatter Plot of Red vs NIR Values", fontsize=14)
# plt.xlabel("Red Band Reflectance", fontsize=12)
# plt.ylabel("NIR Band Reflectance", fontsize=12)

# # Improve appearance
# plt.grid(alpha=0.3)
# plt.tight_layout()

# # Show the plot
# plt.show()

# %%
# # ## Geospatial Map of Clusters
# # Description:
# # A map where each geographic pixel or area is color-coded by its assigned cluster label. This visualization is particularly useful for spatial datasets like Landsat or Sentinel imagery.
# # What You See:
# # A geographic area divided into regions with distinct colors representing clusters.
# # Spatial patterns like vegetation types, water bodies, or urban areas might align with certain clusters.
# # Interpretation:
# # Visually inspect if clusters correspond to meaningful spatial features. For example, a green cluster might correspond to vegetation, while a red cluster might correspond to urban areas.

# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming `final_mosaic` is the original dataset and clustering results are in `cluster_labels`

# # Step 1: Create a mask for valid pixels and reshape cluster labels back to the original spatial shape
# spatial_shape = final_mosaic.dims['y'], final_mosaic.dims['x']  # Replace with actual dimension names
# valid_mask = (final_mosaic['red_band_name'] > 0) & (final_mosaic['nir_band_name'] > 0)  # Adjust mask criteria as needed
# valid_mask = valid_mask.values  # Convert to NumPy array

# # Reshape cluster labels into the original spatial shape
# cluster_map = np.full(spatial_shape, -1, dtype=int)  # Initialize with -1 for invalid pixels
# cluster_map[valid_mask] = cluster_labels  # Assign cluster labels to valid pixels

# # Step 2: Plot the cluster map
# plt.figure(figsize=(10, 8))
# plt.imshow(cluster_map, cmap='tab20', interpolation='none')  # Use a colormap with distinct colors (e.g., 'tab20')
# plt.colorbar(label="Cluster Label")
# plt.title("Geospatial Map of Clusters", fontsize=14)
# plt.xlabel("Longitude", fontsize=12)
# plt.ylabel("Latitude", fontsize=12)

# # Optional: Overlay coordinate grid or other features
# plt.grid(alpha=0.3, linestyle='--')

# # Display the map
# plt.tight_layout()
# plt.show()

# %%
# # # # Cluster Size Distribution
# # Description:
# # A bar chart showing the number of points assigned to each cluster. This helps identify if clusters are well-balanced or if some clusters are disproportionately large or small.
# # What You See:
# # Bars on the x-axis labeled with cluster indices (e.g., 0, 1, 2, etc.) and their corresponding sizes on the y-axis.
# # Some bars might be significantly taller or shorter than others, depending on the cluster balance.
# # Interpretation:
# # Balanced bars suggest that the clusters are well-distributed. A single very tall bar might indicate a dominant cluster, which could be a sign of poor separation or imbalance.

# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming `cluster_labels` contains the cluster assignments for all valid pixels
# n_clusters = 10  # Replace with the number of clusters used in KMeans

# # Calculate the size of each cluster
# unique_labels, counts = np.unique(cluster_labels, return_counts=True)

# # Create a bar chart for cluster sizes
# plt.figure(figsize=(10, 6))
# plt.bar(unique_labels, counts, color='skyblue', edgecolor='black')

# # Add labels and title
# plt.title("Cluster Size Distribution", fontsize=14)
# plt.xlabel("Cluster Label", fontsize=12)
# plt.ylabel("Number of Pixels", fontsize=12)
# plt.xticks(unique_labels)  # Ensure all cluster labels appear as x-ticks

# # Display the plot
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
